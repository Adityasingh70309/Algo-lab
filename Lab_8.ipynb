# %% [markdown]
# <a href="https://colab.research.google.com/github/Adityasingh70309/Algo-lab/blob/main/Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minimum Cost Spanning Tree
# Problem Description:
# A spanning tree of a graph can be defined as a graph with minimal set of edges that connect all vertices. A minimum spanning tree of a graph is a spanning tree of the graph with least weight (where the weight is computed by adding the weights of all the edges in the spanning tree). In general, a graph can have multiple minimum spanning trees. The problem is to find a minimum spanning tree of a graph.

# %% [markdown]
# This implementation uses a dictionary to represent the weighted graph, where the vertices are keys, and the values are dictionaries containing their adjacent vertices and their weights.
#
# Please note that this implementation assumes that the input graph is connected and weighted.
#
# First, let's create a simple graph to demonstrate Prim's algorithm:

# %%
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18},
}

# %% [markdown]
# Now, let's implement Prim's algorithm:

# %%
import heapq

def prim_algorithm(g):
    s_v = list(g.keys())[0]

    e_mst = []
    w_min = 0

    v_set = {s_v}
    pq = []

    for n, w in g[s_v].items():
        heapq.heappush(pq, (w, s_v, n))

    while pq and len(v_set) < len(g):
        w, u, v = heapq.heappop(pq)

        if v in v_set:
            continue

        v_set.add(v)
        e_mst.append((u, v, w))
        w_min += w

        for n_v, w_e in g[v].items():
            if n_v not in v_set:
                heapq.heappush(pq, (w_e, v, n_v))

    return e_mst, w_min

# %% [markdown]
# Now, let's run the Prim's algorithm on the example graph:
# Keep in mind that this example uses a simple representation of a graph, but for more complex cases, you might want to use a library such as NetworkX to represent and manipulate graphs.

# %%
mst, min_weight = prim_algorithm(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  [('A', 'B', 10), ('B', 'C', 12), ('C', 'D', 18)]
# Minimum Weight:  40

# %% [markdown]
# Take Differnt example of input graph as discussed in lecture slide and use above code to verify the output

# %%
g = [
    (0, 1, 4),
    (0, 7, 8),
    (1, 2, 8),
    (1, 7, 11),
    (2, 3, 7),
    (2, 8, 2),
    (2, 5, 4),
    (3, 4, 9),
    (3, 5, 14),
    (4, 5, 10),
    (5, 6, 2),
    (6, 7, 1),
    (6, 8, 6),
    (7, 8, 7)
]
n_v = 9
mst_kruskal, min_weight_kruskal = kruskal_algorithm(g, n_v)
print("MST (Kruskal's):", mst_kruskal)
print("Min Weight (Kruskal's):", min_weight_kruskal)
# Out:
# MST (Kruskal's): [(6, 7, 1), (2, 8, 2), (5, 6, 2), (0, 1, 4), (2, 5, 4), (2, 3, 7), (0, 7, 8), (3, 4, 9)]
# Min Weight (Kruskal's): 37

# %%
mst_prim, min_w_prim = prim_algorithm(graph)
print("MST (Prim's):", mst_prim)
print("Min Weight (Prim's):", min_w_prim)
# Out:
# MST (Prim's): [('A', 'B', 10), ('B', 'C', 12), ('C', 'D', 18)]
# Min Weight (Prim's): 40

# %% [markdown]
# Use same apporach for Kruskal's algorithm

# %%
class DSU:
    def __init__(self, n):
        self.p = list(range(n))
        self.s = [1] * n

    def f(self, i):
        if self.p[i] == i:
            return i
        self.p[i] = self.f(self.p[i])
        return self.p[i]

    def u(self, i, j):
        r_i = self.f(i)
        r_j = self.f(j)
        if r_i != r_j:
            if self.s[r_i] < self.s[r_j]:
                r_i, r_j = r_j, r_i
            self.p[r_j] = r_i
            self.s[r_i] += self.s[r_j]
            return True
        return False

def kruskal_algorithm(g_edges, n_v):
    g_edges.sort(key=lambda x: x[2])
    dsu = DSU(n_v)
    mst_e = []
    min_w = 0
    e_c = 0

    for u, v, w in g_edges:
        if dsu.u(u, v):
            mst_e.append((u, v, w))
            min_w += w
            e_c += 1
            if e_c == n_v - 1:
                break
    return mst_e, min_w
